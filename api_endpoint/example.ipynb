# %%
import requests, json
import secrets

auth = '1pSNVapdzrnGrTjzbHJbXw7q7d7hlzHf'
location = 'http-passive-write'


payload = {
    'name': 'Integration: %s' % secrets.token_urlsafe()[:6],
}

res = requests.post(
    url=f'http://localhost:8016/api-endpoint/v1/{location}', 
    params={'id': 7},
    headers={'Authorization': auth}, 
    data=json.dumps(payload), 
)
print(res.text)
print(res.status_code)
# Out:
# Message Processed Succesfully
# 200
