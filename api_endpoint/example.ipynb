# %%
import requests, json
import secrets

# %%
res = requests.post(
    url=f'http://localhost:8016/api-endpoint/v1/http-passive-write', 
    params={'id': 7},
    headers={'Authorization': '1pSNVapdzrnGrTjzbHJbXw7q7d7hlzHf'}, 
    data=json.dumps({
        'name': 'Write Integration: %s' % secrets.token_urlsafe()[:6],
    }), 
)
print(res.text)
print(res.status_code)

# %%
res = requests.get(
    url=f'http://localhost:8016/api-endpoint/v1/http-passive-read', 
    params={'search_name': 'i'},
    headers={'Authorization': 'CITKabQP1nivZhlPZ087b34vuqtgrd1_2PHvK1fLFsQ'},
)
print(res.text)
print(res.status_code)
